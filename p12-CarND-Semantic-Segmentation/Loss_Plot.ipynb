# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-337c3f5534d7> in <module>()
#       3
#       4 # Prepare the data
# ----> 5 x = np.linspace(0.7112, 0.6564, 0.5213, 0.2736, 0.1543, 0.1827, 0.1168, 0.0798, 0.0717, 0.1447)
#       6
#       7 # Plot the data
#
# TypeError: linspace() takes from 2 to 6 positional arguments but 10 were given

# %%
plt.plot([0.7112,0.6564,0.5213,0.2736,0.1543,0.1827,0.1168,0.0798,0.0717,0.1447,0.0502,0.0645,0.0803,0.0523,0.0364,0.0314, 0.0782,0.0730,0.0215,0.0515])
